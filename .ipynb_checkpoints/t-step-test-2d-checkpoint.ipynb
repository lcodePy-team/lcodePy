# %%
from copy import copy

import numpy as np
import time

from lcode2dPy.plasma.initialization import init_plasma
from lcode2dPy.plasma.solver import CylindricalPlasmaSolver
from lcode2dPy.beam.beam_slice import BeamSlice
from lcode2dPy.beam.beam_io import MemoryBeamSource, MemoryBeamDrain
from lcode2dPy.push_solver import PusherAndSolver
from lcode2dPy.beam.beam_generator import *

from lcode2dPy.config.default_config import default_config

# %%
start_time = time.time()
config = copy(default_config)
config.set('geometry', 'circ')
config.set('window-width', 16)
config.set('window-length', 30)
config.set('plasma-particles-per-cell', 10)
config.set('r-step', 0.01)
config.set('xi-step', 0.01)
#config.set('time-step', 100)
config.set('indication-line-period', 1)
config.set('corrector-steps', 1)

solver = CylindricalPlasmaSolver(config)

R_MAX = config.getfloat('window-width')
D_R = config.getfloat('r-step')
J_MAX = int(R_MAX / D_R)
D_XIP = config.getfloat('xi-step')
xi_max = config.getfloat('window-length')
r_mesh = np.arange(J_MAX + 1) * D_R

# Plasma
xi = 0
fields, particles = init_plasma(config)

# Beam
gamma = 426
angspread = 1e-5
m_proton = 958/0.51
Ipeak_kA = 40/1000

xi_distr = Gauss(vmin=-10, vmax=0)
r_distr = rGauss(vmin=0, vmax=16)
angle_distr = Gauss(sigma=angspread, vmin=None, vmax=None)
pz_distr = Gauss(gamma*m_proton, gamma*m_proton*1e-4, vmin=None, vmax=None)

beam = make_beam(config=config, xi_distr=xi_distr, r_distr=r_distr, ang_distr=angle_distr, pz_distr=pz_distr,
                     Ipeak_kA=Ipeak_kA, q_m=1/m_proton)
particle_dtype = np.dtype([('xi', 'f8'), ('r', 'f8'), ('p_z', 'f8'), ('p_r', 'f8'), ('M', 'f8'), ('q_m', 'f8'),
                           ('q_norm', 'f8'), ('id', 'i8')])
beam = np.array(list(map(tuple, beam.to_numpy())), dtype=particle_dtype)

_beam = BeamSlice(beam.size, beam)
beam_source = MemoryBeamSource(_beam) #TODO mpi_beam_source
beam_drain = MemoryBeamDrain()
# Out:
# Number of particles: 50133
# Number of particles in the middle layer: 200

# %%
PAS = PusherAndSolver(config)

# %%
particles, fields = PAS.step_dt(particles, fields, beam_source, beam_drain, 0)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-4-fe19fe78cbab> in <module>
# ----> 1 particles, fields = PAS.step_dt(particles, fields, beam_source, beam_drain, 0)
#
# ~/Active/CodesMerging/diagnostics/lcode2dPy/lcode2dPy/push_solver.py in step_dt(self, plasma_particles, plasma_fields, beam_source, beam_drain, t)
#      81                 layer_idx - 1,
#      82                 plasma_fields_new,
# ---> 83                 plasma_fields,
#      84             )
#      85             lost_slice, stable_slice, moving_slice = split_beam_slice(
#
# /opt/anaconda3/lib/python3.7/site-packages/numba/dispatcher.py in _compile_for_args(self, *args, **kws)
#     374                 e.patch_message(msg)
#     375
# --> 376             error_rewrite(e, 'typing')
#     377         except errors.UnsupportedError as e:
#     378             # Something unsupported is present in the user code, add help info
#
# /opt/anaconda3/lib/python3.7/site-packages/numba/dispatcher.py in error_rewrite(e, issue_type)
#     341                 raise e
#     342             else:
# --> 343                 reraise(type(e), e, None)
#     344
#     345         argtypes = []
#
# /opt/anaconda3/lib/python3.7/site-packages/numba/six.py in reraise(tp, value, tb)
#     656             value = tp()
#     657         if value.__traceback__ is not tb:
# --> 658             raise value.with_traceback(tb)
#     659         raise value
#     660
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Failed in nopython mode pipeline (step: nopython frontend)
# Invalid use of Function(<numba._DUFunc 'beam_substepping_step'>) with argument(s) of type(s): (array(float64, 1d, C), array(float64, 1d, C), Literal[str](2))
#  * parameterized
# In definition 0:
#     TypeError: cannot call <numba._DUFunc 'beam_substepping_step'> with types (array(float64, 1d, C), array(float64, 1d, C), Literal[str](2))
#     raised from /opt/anaconda3/lib/python3.7/site-packages/numba/npyufunc/dufunc.py:252
# In definition 1:
#     TypeError: cannot call <numba._DUFunc 'beam_substepping_step'> with types (array(float64, 1d, C), array(float64, 1d, C), unicode_type)
#     raised from /opt/anaconda3/lib/python3.7/site-packages/numba/npyufunc/dufunc.py:252
# This error is usually caused by passing an argument of a type that is unsupported by the named function.
# [1] During: resolving callee type: Function(<numba._DUFunc 'beam_substepping_step'>)
# [2] During: typing of call at /home/gorn/Active/CodesMerging/diagnostics/lcode2dPy/lcode2dPy/beam/beam_calculate.py (154)
#
#
# File "lcode2dPy/beam/beam_calculate.py", line 154:
# def init_substepping(beam_slice, time_step, substepping_energy):
#     <source elided>
#     mask = beam_slice.dt == 0
#     dt = beam_substepping_step(beam_slice.q_m[mask], beam_slice.p_z[mask], substepping_energy)
#     ^
#
# [1] During: resolving callee type: type(CPUDispatcher(<function init_substepping at 0x7fd259c0a680>))
# [2] During: typing of call at /home/gorn/Active/CodesMerging/diagnostics/lcode2dPy/lcode2dPy/beam/beam_calculate.py (176)
#
# [3] During: resolving callee type: type(CPUDispatcher(<function init_substepping at 0x7fd259c0a680>))
# [4] During: typing of call at /home/gorn/Active/CodesMerging/diagnostics/lcode2dPy/lcode2dPy/beam/beam_calculate.py (176)
#
#
# File "lcode2dPy/beam/beam_calculate.py", line 176:
#     def move_beam_slice(
#         <source elided>
#         else:
#             init_substepping(beam_slice, time_step, substepping_energy)
#             ^
#
# This is not usually a problem with Numba itself but instead often caused by
# the use of unsupported features or an issue in resolving types.
#
# To see Python/NumPy features supported by the latest release of Numba visit:
# http://numba.pydata.org/numba-doc/latest/reference/pysupported.html
# and
# http://numba.pydata.org/numba-doc/latest/reference/numpysupported.html
#
# For more information about typing errors and how to debug them visit:
# http://numba.pydata.org/numba-doc/latest/user/troubleshoot.html#my-code-doesn-t-compile
#
# If you think your code should work with Numba, please report the error message
# and traceback, along with a minimal reproducer at:
# https://github.com/numba/numba/issues/new

# %%
new_beam=beam_drain.beam_slice()

# %%
import matplotlib.pyplot as plt
plt.hist2d(beam_particles[:-1]['xi'],beam_particles[:-1]['r'],200)
plt.title('Generated')
plt.show()
plt.hist2d(new_beam['xi'],new_beam['r'],200)
plt.title('First iteration')
plt.show()

# %%
beam_particles
# Out:
# array([(-2.49992847e-05, 0.06923084, 425.97861253,  0.00611388, -0.00040532, 5.32359081e-04, 2.34833915e-05,     0),
#        (-4.99985693e-05, 1.53707932, 426.02754508,  0.00562442,  0.00022725, 5.32359081e-04, 2.34833915e-05,     1),
#        (-7.49978541e-05, 1.61773564, 425.98921269,  0.00149669,  0.0021146 , 5.32359081e-04, 2.34833915e-05,     2),
#        ...,
#        (-4.10809798e+00, 0.29282625, 426.04468431, -0.00631573,  0.00195788, 5.32359081e-04, 2.34833915e-05, 50131),
#        (-4.26548834e+00, 1.03980691, 426.07092257, -0.00178742,  0.00031032, 5.32359081e-04, 2.34833915e-05, 50132),
#        (-1.00000000e+05, 0.        ,   0.        ,  0.        ,  0.        , 1.00000000e+00, 0.00000000e+00,     0)],
#       dtype=[('xi', '<f8'), ('r', '<f8'), ('p_z', '<f8'), ('p_r', '<f8'), ('M', '<f8'), ('q_m', '<f8'), ('q_norm', '<f8'), ('id', '<i8')])

# %%
new_beam.sort(order=['id'])

# %%
new_beam
# Out:
# array([(-19.47043746, 0.06929879, 426.08108234,  0.0043575 , -0.00040538, 0.00053236, 2.34833915e-05,     0),
#        (-19.47015916, 1.53702123, 426.08129016, -0.01457423,  0.00022727, 0.00053236, 2.34833915e-05,     1),
#        (-19.47067811, 1.61762721, 426.0395938 , -0.01820545,  0.00211476, 0.00053236, 2.34833915e-05,     2),
#        ...,
#        (-23.48425702, 0.74963054, 425.95279388, -0.01243103, -0.00070043, 0.00053236, 2.34833915e-05, 50130),
#        (-23.57892142, 0.2926853 , 425.94842501, -0.01540301,  0.00195827, 0.00053236, 2.34833915e-05, 50131),
#        (-23.73579637, 1.03958806, 426.00569133, -0.03193593,  0.00031037, 0.00053236, 2.34833915e-05, 50132)],
#       dtype=[('xi', '<f8'), ('r', '<f8'), ('p_z', '<f8'), ('p_r', '<f8'), ('M', '<f8'), ('q_m', '<f8'), ('q_norm', '<f8'), ('id', '<i8')])

# %%
plt.plot(np.array(fields.E_z))
plt.title('E_z')
plt.show()
plt.plot(np.array(fields.E_r))
plt.title('E_r')
plt.show()
